# %%
import pandas as pd
from IPython.display import HTML 
import matplotlib.pyplot as plt

# %%
weather_data = pd.read_csv("Resources/cities.csv")

# %%
weather_data.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  jacareacanga           0      BR  1528902000        62  -6.22
# 1        1    kaitangata         100      NZ  1528905304        94 -46.28
# 2        2      goulburn          20      AU  1528905078        91 -34.75
# 3        3          lata          76      IN  1528905305        89  30.78
# 4        4    chokurdakh           0      RU  1528905306        88  70.62
#
#       Lng  Max Temp  Wind Speed
# 0  -57.76     89.60        6.93
# 1  169.85     42.61        5.64
# 2  149.72     44.32       10.11
# 3   78.62     59.89        0.94
# 4  147.90     32.17        2.95

# %%
#Don't run again as it will disrupt weather_data.html that has been created and formatted
# weather_data.to_html("weather_data.html", index=False, classes="table table-striped table-hover")

# %%
# final_df = HTML(weather_data.to_html(index=False, classes="table table-striped table-hover"))

# %%
# final_df

# %%
#final_df.to_html("weather_data.html")

# %%
#create scatter plot WindSpeed vs.Temperature using pandas plot

weather_data.plot.scatter(x="Max Temp", y='Wind Speed', grid=True, 
                               alpha=1, edgecolors ='black', title = f"Max Temperature vs. Wind Speed (01/05/17)")
#test plot
plt.plot()
#savefit
plt.savefig("Resources/assets/images/Fig5.png")
#show plot
plt.show()
